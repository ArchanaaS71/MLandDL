# %% [markdown]
# K - Nearest Neighbors
# If you are using K and you have an even number of classes (e.g. 2) it is a good idea to choose a K value with an **odd number** to avoid a tie. And the inverse, use an even number for K when you have an odd number of classes.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Based on euclidean or manhataan distance

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Cross validation
#  * Hold out
#  * Leave one out
#  * K-Fold Cross Validation
#
# Grid Search:
# * Identify the hyper parameter needed for the model
# * Best fitting model
#
# FOR HYPER PARAMETER TUNING WE HAVE THESE LIBRARIES
# * GridSearchCV
# * Optuna

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('/content/Life_expectancy_dataset.csv',encoding='utf-8')
data.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe3 in position 1: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-6-ddbf9ff4cab1> in <cell line: 3>()
#       1 import pandas as pd
# ...
