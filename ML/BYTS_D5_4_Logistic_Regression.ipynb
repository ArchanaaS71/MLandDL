# %% [markdown]
# Classiifcation types:
# * Binary classification
# * Multiclass Classification
#
# \
#
#
# ![image.png](data:image/png;base64,...)
# \
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
#
# **log(y/1-y) = c+b1x1+b2x2+......**\
# slow incremental in gradient descent
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# p = e^

# %% [markdown]
# **TYPES OF LOGISTIC REGRESSION**\
# * Binary logistic regression\
# * Multinomial logistic regression\
# *
# Ordinal Logistic Regression - three  or more values in a range like ratings etc
#
#
# **Where it can be used?**
# * Which major will a college student choose, Given grades , stated likes and dislikes?\
# * which candidate will a person vote for, given a particular demographocs characteristics?\
# * Which country will a firm locate an office in , given the cahracteristics of th firm and of the various candidate countries?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
